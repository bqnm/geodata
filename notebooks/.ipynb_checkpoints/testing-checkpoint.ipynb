# %%
import pandas as pd
import matplotlib
import numpy
import pprint as p
import re

# %%
og = pd.read_csv('./data/childcarecenters.csv')

# %%
p.pprint(og.shape)
# Out:
# (1046, 19)

# %%
df1 = og.copy()

# %%
for i in range(len(df1['geometry'])): 
    if type(df1['geometry'][i]) == str:
        x = eval(df1['geometry'][i])
        df1.loc[i,['geometry']] = x
# Out:
# <class 'dict'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-caf1cb3e9e3b> in <module>
#       1 for i in range(len(df1['geometry'])):
#       2     print(type(df1['geometry'][i]))
# ----> 3     x = eval(df1['geometry'][i])
#       4     df1.loc[i,['geometry']] = x
#
# TypeError: eval() arg 1 must be a string, bytes or code object

# %%
# Out:
# str
